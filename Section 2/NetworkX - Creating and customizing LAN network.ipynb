# %%
import sys
import matplotlib.pyplot as plt
import networkx as nx

G = nx.grid_2d_graph(5, 5)  # 5x5 grid
try:  # Python 2.6+
    nx.write_adjlist(G, sys.stdout)  # write adjacency list to screen
except TypeError:  # Python 3.x
    nx.write_adjlist(G, sys.stdout.buffer)  # write adjacency list to screen
# write edgelist to grid.edgelist
nx. write_edgelist(G, path="grid.edgelist", delimiter=":")
# read edgelist from grid.edgelist
H = nx.read_edgelist(path="grid.edgelist", delimiter=":")

nx.draw(H)
plt.show()
# Out:
# #C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py -f C:\Users\harish\AppData\Roaming\jupyter\runtime\kernel-6821525d-bbad-477a-8397-5a88f8a0eada.json
# # GMT Tue Mar 20 10:16:10 2018
# # grid_2d_graph
# (0, 0) (1, 0) (0, 1)
# (0, 1) (1, 1) (0, 2)
# (0, 2) (1, 2) (0, 3)
# (0, 3) (1, 3) (0, 4)
# (0, 4) (1, 4)
# (1, 0) (2, 0) (1, 1)
# (1, 1) (2, 1) (1, 2)
# (1, 2) (2, 2) (1, 3)
# (1, 3) (2, 3) (1, 4)
# (1, 4) (2, 4)
# (2, 0) (3, 0) (2, 1)
# (2, 1) (3, 1) (2, 2)
# (2, 2) (3, 2) (2, 3)
# (2, 3) (3, 3) (2, 4)
# (2, 4) (3, 4)
# (3, 0) (4, 0) (3, 1)
# (3, 1) (4, 1) (3, 2)
# (3, 2) (4, 2) (3, 3)
# (3, 3) (4, 3) (3, 4)
# (3, 4) (4, 4)
# (4, 0) (4, 1)
# (4, 1) (4, 2)
# (4, 2) (4, 3)
# (4, 3) (4, 4)
# (4, 4)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %% [markdown]
# ## Import NetworkX module

# %%
import networkx as nx

# %% [markdown]
# ## Creating an empty graph

# %%
G=nx.Graph()

# %% [markdown]
# ## Adding Nodes

# %%
G.add_node(1)

# %%
G.add_nodes_from([2,3])

# %% [markdown]
# ### Adding Edges

# %%
G.add_edge(1,2)

# %%
e=(2,3)
G.add_edge(*e)

# %%
G.add_edges_from([(1,2),(1,3)])

# %% [markdown]
# ### View Nodes

# %%
 G.number_of_nodes()
# Out:
# 3

# %% [markdown]
# ### View Edges

# %%
G.number_of_edges()
# Out:
# 3

# %%
G.nodes()
# Out:
# [1, 2, 3]

# %%
G.edges()
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
G.neighbors(1)
# Out:
# [2, 3]

# %% [markdown]
# ### Drawing Graphs

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(G)
# Out:
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
plt.show()

# %%
G.add_node('node4')

# %%
nx.draw(G)
plt.show()
# Out:
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
G.add_edges_from([(2,'node4'),(3,'node4')])

# %%
nx.draw(G,  with_labels=True, font_weight='bold')
plt.show()
# Out:
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %% [markdown]
# ### Adding attributes to graphs, nodes, and edges

# %%
G.graph['Network'] = 'LAN'

# %%
G.graph
# Out:
# {'Network': 'LAN'}

# %%
G.add_node(5, OS='Mac')

# %%
G.nodes('data')
# Out:
# [(1, {}), (2, {}), (3, {}), ('node4', {}), (5, {'OS': 'Mac'})]

# %%
G.add_edge(3, 5, weight=4.7, color='blue')

# %%
nx.draw(G,  with_labels=True, font_weight='bold')
plt.show()
# Out:
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\harish\Anaconda2\envs\python3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %% [markdown]
# ## Directed Graphs

# %%
DG = nx.DiGraph()

# %%
DG.add_weighted_edges_from([(1, 2, 0.5), (3, 1, 0.75)])

# %%
DG.out_degree(1, weight='weight')
# Out:
# 0.5

# %%
DG.degree(1, weight='weight')
# Out:
# 1.25

# %%
list(DG.successors(1))
# Out:
# [2]

# %%
list(DG.neighbors(1))
# Out:
# [2]

# %% [markdown]
# ## Analyzing graphs

# %%
G = nx.Graph()
G.add_edges_from([(1, 2), (1, 3)])
G.add_node("spam")       # adds node "spam"
list(nx.connected_components(G))

nx.clustering(G)
# Out:
# {1: 0.0, 2: 0.0, 3: 0.0, 'spam': 0.0}

# %%
sp = dict(nx.all_pairs_shortest_path(G))
sp[3]
# Out:
# {1: [3, 1], 2: [3, 1, 2], 3: [3]}
